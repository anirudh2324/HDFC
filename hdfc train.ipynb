# %%
import pandas as pd
import numpy as np

# %%
hdfc_data=pd.read_csv('Train.csv')
# Out:
# C:\Users\ANIRUDH\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (746,835) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
hdfc_data.head()
# Out:
#         Col1  Col2          Col3          Col4          Col5          Col6  \
# 0    RIGHGSN     1  1.086711e+04  8.648345e+03  1.576618e+04  2.890466e+04
# 1  RIMHI5ZGP     0  2.584312e+05  2.179633e+05  1.866287e+05  1.866287e+05
# 2  RIHOG1SZU     0  1.459355e+07  1.260060e+07  1.100315e+07  1.010315e+07
# 3  RIHOLMQWU     0  6.727043e+05  8.181116e+05  6.794893e+05  6.794893e+05
# 4  RIHO584ET     0 -1.218742e+06 -3.005361e+06 -1.666241e+05 -2.403574e+06
#
#            Col7          Col8          Col9         Col10  ...  Col2388  \
# 0  5.273655e+03  2.346153e+04  1.285597e+04  2.871509e+04  ...        0
# 1  2.154519e+05  1.923615e+05  1.726538e+05  1.666974e+05  ...        0
# 2  1.879882e+07  1.514035e+07  5.320778e+06  6.906324e+06  ...        0
# 3  8.257254e+05  7.605803e+05  3.577134e+05  4.236612e+05  ...        0
# 4  2.583183e+06  2.086546e+06  5.938358e+06  5.446532e+06  ...        0
#
#    Col2389  Col2390  Col2391  Col2392  Col2393  Col2394  Col2395  Col2396  \
# ...

# %%
hdfc_data.isnull().sum()
# Out:
# Col1           0
# Col2           0
# Col3           0
# Col4           0
# Col5           0
# Col6           0
# Col7           0
# Col8           0
# Col9           0
# Col10          0
# Col11          0
# Col12          0
# Col13       1249
# Col14       1244
# Col15       1246
# Col16       1243
# Col17       1470
# Col18       2860
# Col19      14759
# Col20      14319
# Col21       1241
# Col22       1244
# Col23       1243
# Col24       1246
# Col25          0
# Col26          0
# Col27        682
# Col28      12260
# Col29          0
# Col30          0
#            ...
# Col2368        0
# Col2369        0
# Col2370        0
# Col2371        0
# Col2372        0
# Col2373        0
# Col2374        0
# Col2375        0
# Col2376        0
# Col2377        0
# Col2378        0
# Col2379        0
# Col2380        0
# Col2381        0
# Col2382        0
# Col2383        0
# Col2384        0
# Col2385        0
# Col2386        0
# Col2387        0
# Col2388        0
# ...

# %%
hdfc_data=hdfc_data.fillna(hdfc_data.mean())

# %%
a = hdfc_data.dtypes.reset_index()
a.columns = ['name','dtype']
#obj_dtype = a.groupby('dtype')
#obj_dtype.first()

# %%
a.groupby(['dtype']).sum()
# Out:
#                                                       name
# dtype
# int64    Col2Col29Col30Col31Col32Col33Col34Col35Col36Co...
# float64  Col3Col4Col5Col6Col7Col8Col9Col10Col11Col12Col...
# object                                    Col1Col747Col836

# %%
hdfc_data.drop('Col1', axis = 1, inplace = True)
hdfc_data.drop('Col747', axis = 1, inplace = True)
hdfc_data.drop('Col836', axis = 1, inplace = True)

# %%
hdfc_data.fillna(hdfc_data.mean(), inplace= True)

# %%
from sklearn import tree

# %%
ctree=tree.DecisionTreeClassifier()
ctreea
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
x = hdfc_data.drop('Col2',axis = 1)

# %%
y = hdfc_data['Col2']

# %%
ctree.fit(x,y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
ctree.feature_importances_
# Out:
# array([0.00031249, 0.00045376, 0.00090751, ..., 0.00114389, 0.00090751,
#        0.        ])

# %%
comp_df=pd.DataFrame()
comp_df['col']=x.columns
comp_df['imp']=ctree.feature_importances_*100

comp_df
# Out:
#           col       imp
# 0        Col3  0.031249
# 1        Col4  0.045376
# 2        Col5  0.090751
# 3        Col6  0.000000
# 4        Col7  0.349739
# 5        Col8  0.173346
# 6        Col9  0.159544
# 7       Col10  0.466472
# 8       Col11  0.185267
# 9       Col12  0.390404
# 10      Col13  0.086581
# 11      Col14  0.018903
# 12      Col15  0.193591
# 13      Col16  0.008751
# 14      Col17  0.189537
# 15      Col18  0.321565
# 16      Col19  0.113679
# 17      Col20  0.124970
# 18      Col21  0.325501
# 19      Col22  0.584119
# 20      Col23  0.186688
# 21      Col24  0.187598
# 22      Col25  0.339806
# 23      Col26  0.417995
# 24      Col27  0.442348
# 25      Col28  0.469975
# 26      Col29  0.063305
# 27      Col30  0.000000
# 28      Col31  0.056504
# 29      Col32  0.000000
# ...       ...       ...
# 2361  Col2368  0.000000
# 2362  Col2369  0.000000
# 2363  Col2370  0.000000
# 2364  Col2371  0.000000
# 2365  Col2372  0.000000
# 2366  Col2373  0.000000
# ...

# %%
comp_df=comp_df.sort_values('imp',ascending=False)

# %%
a = comp_df.head(550)

# %%
a.imp.sum()
# Out:
# 93.16951057469902

# %%
 x_cols = a['col'].tolist()
print(x_cols)
# Out:
# ['Col636', 'Col874', 'Col649', 'Col875', 'Col166', 'Col633', 'Col92', 'Col614', 'Col666', 'Col22', 'Col1830', 'Col713', 'Col264', 'Col872', 'Col912', 'Col440', 'Col177', 'Col409', 'Col178', 'Col722', 'Col28', 'Col10', 'Col932', 'Col575', 'Col270', 'Col27', 'Col180', 'Col467', 'Col855', 'Col627', 'Col107', 'Col163', 'Col26', 'Col876', 'Col442', 'Col773', 'Col390', 'Col12', 'Col291', 'Col279', 'Col7', 'Col683', 'Col255', 'Col759', 'Col83', 'Col802', 'Col25', 'Col604', 'Col21', 'Col18', 'Col466', 'Col864', 'Col564', 'Col209', 'Col543', 'Col873', 'Col393', 'Col741', 'Col134', 'Col150', 'Col703', 'Col885', 'Col175', 'Col37', 'Col430', 'Col155', 'Col643', 'Col114', 'Col193', 'Col881', 'Col795', 'Col208', 'Col43', 'Col196', 'Col1687', 'Col182', 'Col792', 'Col1890', 'Col652', 'Col243', 'Col253', 'Col79', 'Col106', 'Col355', 'Col715', 'Col1822', 'Col880', 'Col2212', 'Col850', 'Col540', 'Col241', 'Col1166', 'Col286', 'Col408', 'Col461', 'Col228', 'Col1781', 'Col582', 'Col624', 'Col930', 'Col68
# ...

# %%
x = hdfc_data[a['col']]

# %%
x
# Out:
#           Col636    Col874    Col649    Col875     Col166    Col633  \
# 0       0.460104  4.015786  0.000000  4.015786   2.636174  0.000000
# 1       0.000000  2.984058  0.000000  2.984058   9.210323  0.000000
# 2       0.002855  2.271018  0.000000  2.271018   3.219582  0.000068
# 3       0.000000  3.065040  0.000000  3.065040   2.778929  0.001353
# 4       2.520248  3.598077  0.001000  3.598077   2.579341  0.010466
# 5       0.004261  1.395357  0.000000  1.395357   2.630781  0.000000
# 6       0.000000  1.013133  0.000000  1.013133   1.083027  0.000000
# 7       0.032270  0.746886  0.000000  0.787590   1.172812  0.000000
# 8       0.150280  1.400776  0.000000  1.400776   1.338199  0.000393
# 9       0.055517  1.343063  0.000000  1.258210   6.989098  0.000000
# 10      0.000000  0.953987  0.000000  0.953987   1.298676  0.000069
# 11      1.264829  0.850316  0.000000  0.850316   2.619669  0.000684
# 12      0.645817  1.346534  0.015000  1.346534   8.599034  0.001510
# ...

# %%
x.shape
# Out:
# (17521, 550)

# %%
ctree.fit(x,y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics
x_train, x_test, y_train, y_test = train_test_split(x, y , test_size = 0.4, random_state = 1 )
ctree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
y_train_pred = ctree.predict(x_train)
print('Train accuracy = ', metrics.accuracy_score(y_train, y_train_pred))

y_test_pred = ctree.predict(x_test)
print('Test accuracy = ', metrics.accuracy_score(y_test, y_test_pred))
# Out:
# Train accuracy =  0.9920091324200914
# Test accuracy =  0.8302182907690113

# %%
metrics.recall_score(y_test,y_test_pred)
# Out:
# 0.1971631205673759

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = { "criterion"      : ['gini', 'entropy'],    
               "max_features"   : [1, 2,3,4,500 ],             
               "splitter"       : ['best', 'random'],  
               "min_samples_leaf" : [2, 3],
               "max_depth"        : [1,2,3,4,5]
                }

# %%
optimized_tree = GridSearchCV(ctree, param_grid,verbose = 2 , scoring = 'f1', cv=21)  #inplace of accuracy use scoring = 'recall'

# %%
optimized_tree.fit(x_train, y_train)
# Out:
# Fitting 21 folds for each of 200 candidates, totalling 4200 fits
# [CV] criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, splitter=best
# [CV]  criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, splitter=best, total=   0.0s
# [CV] criterion=gini, max_depth=1, max_features=1, min_samples_leaf=2, splitter=best
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# C:\Users\ANIRUDH\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\ANIRUDH\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# ...

# %%
optimized_tree.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 5,
#  'max_features': 500,
#  'min_samples_leaf': 3,
#  'splitter': 'best'}

# %%
optimized_tree.best_estimator_
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=5,
#             max_features=500, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=3, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
final_model = optimized_tree.best_estimator_

# %%
y_test_pred = final_model.predict(x_test)
y_test_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
metrics.recall_score(y_test,y_test_pred)
# Out:
# 0.03687943262411347

# %%
metrics.accuracy_score(y_test,y_test_pred)
# Out:
# 0.8934227421886146

# %%
import pickle

# %%
pickle.dump(final_model, open('HDFC_PK_FILE1_lst.pk', 'wb'))
